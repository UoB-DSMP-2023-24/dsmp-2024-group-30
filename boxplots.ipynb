# %%
import pandas as pd
import seaborn as sb

df = pd.read_csv('simulated_transaction_2024.csv')
# Out:
# C:\Users\carlo\AppData\Local\Temp\ipykernel_17816\86173720.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# Separate the dataset into two based on the Amount
outgoing_payments = df[df['Amount'] < 0]
incoming_payments = df[df['Amount'] > 0]

# Display the first few rows of each dataset to confirm
(outgoing_payments.head(), incoming_payments.head())
# Out:
# (          Date Timestamp   Account No  Balance  Amount  \
#  2   01/01/2023     00:00  472213568.0   3012.0  -780.0
#  7   01/01/2023     00:00  768271776.0   2840.0  -780.0
#  11  01/01/2023     00:00  350921975.0   1998.5  -460.0
#  13  01/01/2023     00:00  455831435.0   2603.1  -650.0
#  18  01/01/2023     00:00  172084472.0   1149.0 -1300.0
#
#      Third Party Account No Third Party Name
#  2              283027736.0              NaN
#  7              215404070.0              NaN
#  11             633362865.0              NaN
#  13             442079728.0              NaN
#  18             407574996.0              NaN  ,
#           Date Timestamp   Account No  Balance   Amount  \
#  0  01/01/2023     00:00  678330503.0  2971.00  1584.00
#  1  01/01/2023     00:00  472213568.0  3792.00  1950.00
#  3  01/01/2023     00:00  283027736.0  1787.00   780.00
#  4  01/01/2023     00:00  624500124.0  3226.00  1825.00
#  5  01/01/2023     00:00  203466392.0  4607.66  2841.66
#
# ...

# %%
unique_third_party_names = outgoing_payments['Third Party Name'].unique()

# Print unique Third Party Names
for name in unique_third_party_names:
    print(name)
# Out:
# nan
# Halifax
# LBG
# Blizzard
# Xbox
# Mojang Studios
# PureGym
# Disney
# Netflix
# Grand Union BJJ
# Amazon
# SquareOnix
# Deliveroo
# JustEat
# Coop Local
# Selfridges
# Sainsbury
# AMAZON
# The Works
# Blackwell's
# Fat Face
# Topshop
# Matalan
# Foyles
# Tesco
# Wool
# Hobby Lobby
# Revella
# Sainsbury Local
# Starbucks
# Loosely Fitted
# Stitch By Stitch
# Coffee #1
# Hobbycraft
# A Yarn Story
# Craftastic
# Kings Arms
# Costa Coffee
# The Crown
# Lloyds Pharmacy
# Rose & Crown
# Fitted Stitch
# Gamestation
# CeX
# Etsy
# Five Senses Art
# Sports Direct
# Cass Art
# Brilliant Brushes
# Boots
# Reebok
# JD Sports
# Head
# Frankie & Bennies
# Gap Kids
# North Face
# Town High
# Collector Cave
# Barbiee Boutique
# RugbyFields
# Mamas & Papas
# Lavender Primary
# Remedy plus care
# Specsavers
# Kew House
# HMV
# Vision Express
# Millets
# Pets Corner
# Mothercare
# A Cut Above
# Happy Days Home
# Mountain Warehouse
# Victoria Park
# University College Hospital

# %%
third_party_name_counts = outgoing_payments['Third Party Name'].value_counts()

# Print the counts of each unique Third Party Name
print(third_party_name_counts.to_string())
# Out:
# Third Party Name
# Tesco                          33905
# Sports Direct                  16248
# Topshop                        10328
# Fat Face                        9308
# PureGym                         8286
# Matalan                         7846
# Netflix                         7775
# Amazon                          7571
# JustEat                         7152
# Deliveroo                       6967
# The Works                       6697
# Five Senses Art                 5955
# Revella                         5354
# Starbucks                       4821
# Blizzard                        4438
# SquareOnix                      4379
# Xbox                            4372
# Mojang Studios                  4369
# Disney                          3952
# Blackwell's                     3846
# Loosely Fitted                  3718
# Grand Union BJJ                 3657
# Sainsbury Local                 3155
# Sainsbury                       3117
# Halifax                         3052
# ...

# %%
third_party_name_counts_incoming = incoming_payments['Third Party Name'].value_counts()

# Print the counts of each unique Third Party Name
print(third_party_name_counts_incoming.to_string())
# Out:
# Third Party Name
# Westport Care Home             408
# Happy Days Home                307
# CPA                            286
# Premier Finance                276
# LBG                            264
# Halifax                        231
# Fat Face                       228
# Green Park Academy             228
# Matalan                        220
# Selfridges                     216
# Remedy plus care               209
# Lavender Primary               204
# Fitted Stitch                  203
# Vision Express                 187
# Lloyds Pharmacy                186
# Craftastic                     179
# University College Hospital    176
# Sainsbury                      176
# Hobbycraft                     176
# Hobby Lobby                    176
# Tesco                          167
# Pets Corner                    156
# Boots                          152
# Jollyes                        143
# Head                           120
# A Cut Above                    120
# ...

# %%
unique_outgoing_count = outgoing_payments['Third Party Name'].nunique()

print("Number of unique Third Party Names:", unique_outgoing_count)
# Out:
# Number of unique Third Party Names: 74

# %%
unique_incoming_count = incoming_payments['Third Party Name'].nunique()

print("Number of unique Third Party Names:", unique_incoming_count)
# Out:
# Number of unique Third Party Names: 46

# %%
unique_third_party_names_count = df['Third Party Name'].nunique()

print("Number of unique Third Party Names:", unique_third_party_names_count)
# Out:
# Number of unique Third Party Names: 83

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Disney', 'Netflix', 'Amazon', 'Etsy']
selected_transactions = df[df['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Streaming Category')
plt.xlabel('Transferred Location Account')
plt.ylabel('Money Transfer Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Sports Direct', 'Reebok', 'JD Sports', 'Head']
selected_transactions = df[df['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Sports Category')
plt.xlabel('Transferred Location Account')
plt.ylabel('Money Transfer Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['The Crown', 'Rose & Crown', 'Kings Arms']
selected_transactions = df[df['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Pub Category')
plt.xlabel('Transferred Location Account')
plt.ylabel('Money Transfer Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Pets Corner', 'Pets at Home', 'Jollyes']
selected_transactions = df[df['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Pet Category')
plt.xlabel('Transferred Location Account')
plt.ylabel('Money Transfer Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Lavender Fields', 'Victoria Park', 'Green Park', 'RugbyFields']
selected_transactions = df[df['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Park Category')
plt.xlabel('Transferred Location Account')
plt.ylabel('Money Transfer Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Collector Cave', 'HMV']
selected_transactions = df[df['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Music Category')
plt.xlabel('Transferred Location Account')
plt.ylabel('Money Transfer Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Disney', 'Netflix', 'Amazon', 'Etsy']
selected_transactions = df[df['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Streaming Category')
plt.xlabel('Transferred Location Account')
plt.ylabel('Money Transfer Amount')
plt.show()

# %%
average_amount_per_third_party = df.groupby('Third Party Name')['Amount'].mean()

# Sort the results in ascending order
average_amount_per_third_party_sorted = average_amount_per_third_party.sort_values()

# Display the average amount per transaction for each unique Third Party Name in ascending order
print(average_amount_per_third_party_sorted.to_string())
# Out:
# Third Party Name
# Halifax                        -538.996954
# LBG                            -447.457480
# Mothercare                     -280.000000
# Specsavers                     -270.000000
# Gap Kids                       -260.000000
# Kew House                      -203.333333
# Mamas & Papas                  -186.666667
# HMV                            -150.000000
# Town High                      -140.000000
# RugbyFields                    -140.000000
# Frankie & Bennies              -135.000000
# Topshop                        -103.670630
# Revella                         -86.848764
# Millets                         -70.000000
# Grand Union BJJ                 -67.424228
# Tesco                           -66.073070
# JD Sports                       -63.993286
# Sports Direct                   -61.277883
# Reebok                          -60.993792
# Loosely Fitted                  -59.246019
# Fat Face                        -47.702281
# ...

# %%
average_incoming = incoming_payments.groupby('Third Party Name')['Amount'].mean()

# Sort the results in ascending order
average_incoming_sorted = average_incoming.sort_values()

# Display the average amount per transaction for each unique Third Party Name in ascending order
print(average_incoming_sorted.to_string())
# Out:
# Third Party Name
# CeX                            1675.375000
# Starbucks                      1700.422222
# Happy Days Home                1710.016287
# Westport Care Home             1716.029412
# Costa Coffee                   1722.040000
# Kings Arms                     1736.660000
# Victoria Park                  1736.920000
# Lavender Fields                1737.920000
# Green Park                     1738.920000
# The Crown                      1743.511111
# Rose & Crown                   1743.511111
# Tesco                          1754.401198
# Gamestation                    1813.750000
# Craftastic                     1858.770950
# Sainsbury                      1882.187500
# Hobby Lobby                    1896.250000
# Hobbycraft                     1912.812500
# North Face                     1913.333333
# Collector Cave                 1922.333333
# Stitch By Stitch               1923.061224
# A Yarn Story                   1951.250000
# ...

# %%
average_outgoing = outgoing_payments.groupby('Third Party Name')['Amount'].mean()

# Sort the results in ascending order
average_outgoing_sorted = average_outgoing.sort_values()

# Display the average amount per transaction for each unique Third Party Name in ascending order
print(average_outgoing_sorted.to_string())
# Out:
# Third Party Name
# Halifax                       -839.431520
# LBG                           -798.159567
# Victoria Park                 -290.000000
# Mothercare                    -280.000000
# Specsavers                    -270.000000
# Barbiee Boutique              -270.000000
# North Face                    -270.000000
# Gap Kids                      -260.000000
# Remedy plus care              -220.000000
# Vision Express                -220.000000
# Pets Corner                   -210.000000
# Kew House                     -203.333333
# A Cut Above                   -200.000000
# Happy Days Home               -200.000000
# Head                          -200.000000
# Mamas & Papas                 -186.666667
# Lavender Primary              -163.333333
# HMV                           -150.000000
# Collector Cave                -143.326667
# RugbyFields                   -140.000000
# Town High                     -140.000000
# Frankie & Bennies             -135.000000
# ...

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Halifax', 'LBG']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Halifax', 'LBG']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Victoria Park', 'Mothercare', 'Specsavers', 'Barbiee Boutique', 'North Face', 'Gap Kids']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Victoria Park', 'Mothercare', 'Specsavers', 'Barbiee Boutique', 'North Face', 'Gap Kids']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Remedy plus care', 'Vision Express', 'Pets Corner', 'Kew House', 'A Cut Above', 'Happy Days Home', 'Head']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Remedy plus care', 'Vision Express', 'Pets Corner', 'Kew House', 'A Cut Above', 'Happy Days Home', 'Head']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Mamas & Papas', 'Lavender Primary', 'HMV', 'Collector Cave']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Mamas & Papas', 'Lavender Primary', 'HMV', 'Collector Cave']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Banking Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['RugbyFields', 'Town High']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the School Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['RugbyFields', 'Town High']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the School Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Frankie & Bennies']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Restaurant Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Frankie & Bennies']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Restaurant Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['North Face', 'Fat Face', 'Topshop', 'Matalan', 'Revella']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Clothing Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['North Face', 'Fat Face', 'Topshop', 'Matalan', 'Revella']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Clothing Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Grand Union BJJ', 'PureGym']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Restaurant Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Grand Union BJJ', 'PureGym']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Restaurant Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['CeX', 'Gamestation']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Gaming Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['CeX', 'Gamestation']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Gaming Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['University College Hospital']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Hospital Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['University College Hospital']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Hospital Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Tesco', 'Sainsbury', 'Sainsbury Local', 'Coop Local']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Grocery Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Tesco', 'Sainsbury', 'Sainsbury Local', 'Coop Local']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Grocery Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Millets', 'JD Sports', 'Sports Direct', 'Reebok', 'Loosely Fitted', 'Selfridges', 'Fitted Stitch', 'Mountain Warehouse']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Sports Stores Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Millets', 'JD Sports', 'Sports Direct', 'Reebok', 'Loosely Fitted', 'Selfridges', 'Fitted Stitch', 'Mountain Warehouse']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Sports Stores Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Hobbycraft', 'Five Senses Art', 'Brilliant Brushes', 'Cass Art', 'Craftastic', 'Hobby Lobby', 'A Yarn Story', 'Wool', 'The Works']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Art Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Hobbycraft', 'Five Senses Art', 'Brilliant Brushes', 'Cass Art', 'Craftastic', 'Hobby Lobby', 'A Yarn Story', 'Wool', 'The Works']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Art Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ["Foyles", "Blackwell's"]
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Book Stores Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ["Foyles", "Blackwell's"]
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Book Stores Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Deliveroo', 'JustEat']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Delivery Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Deliveroo', 'JustEat']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Delivery Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Lloyds Pharmacy', 'Boots']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Healthcare Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Lloyds Pharmacy', 'Boots']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Healthcare Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['AMAZON', 'Amazon', 'Etsy']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Healthcare Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['AMAZON', 'Amazon', 'Etsy']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Healthcare Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Netflix', 'Blizzard', 'SquareOnix', 'Disney', 'Xbox', 'Mojang Studios']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Healthcare Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Netflix', 'Blizzard', 'SquareOnix', 'Disney', 'Xbox', 'Mojang Studios']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Healthcare Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['The Crown', 'Rose & Crown', 'Kings Arms']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Pub Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['The Crown', 'Rose & Crown', 'Kings Arms']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Pub Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Coffee #1', 'Costa Coffee', 'Starbucks']
selected_transactions = outgoing_payments[outgoing_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Coffee Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()

# %%
# Filter the data for transactions with "TransferredLocationAccount" equals to Bar Category
selected_accounts = ['Coffee #1', 'Costa Coffee', 'Starbucks']
selected_transactions = incoming_payments[incoming_payments['Third Party Name'].isin(selected_accounts)]

# Create a boxplot for the 'MoneyTransferAmount' column for transactions with the selected accounts
plt.figure(figsize=(10, 6))
sns.boxplot(data=selected_transactions, x='Third Party Name', y='Amount')
plt.title('Boxplots of Transactions for the Coffee Category')
plt.xlabel('Third Party Name')
plt.ylabel('Outgoing Transaction Amount')
plt.show()
